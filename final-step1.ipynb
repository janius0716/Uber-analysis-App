# %%
# 安装kaggle库（如果未安装）
# !pip install kaggle --upgrade

import os
import json
import zipfile

# 配置Kaggle API的认证信息
kaggle_info = {
    "username": "zhijiazhou",
    "key": "ba4f99327f8bd265c669d06eabe0be8b"
}

# 创建.kaggle目录（如果不存在）
kaggle_dir = os.path.expanduser("~/.kaggle")
os.makedirs(kaggle_dir, exist_ok=True)

# 写入kaggle.json配置文件
kaggle_json_path = os.path.join(kaggle_dir, "kaggle.json")
with open(kaggle_json_path, "w") as f:
    json.dump(kaggle_info, f)

# 设置文件权限（避免安全警告）
os.chmod(kaggle_json_path, 0o600)

# 下载数据集（使用Kaggle API命令）
dataset_url = "yasserh/uber-fares-dataset"  # 从URL提取的数据集路径
# !kaggle datasets download -d {dataset_url}

# 解压下载的zip文件
zip_filename = "uber-fares-dataset.zip"
with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
    zip_ref.extractall()

# 验证文件是否存在
csv_filename = "uber.csv"
if os.path.exists(csv_filename):
    print(f"数据集已成功保存为CSV文件：{csv_filename}")
else:
    print("数据集下载或解压失败")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting kaggle
#   Downloading kaggle-1.7.4.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: bleach in c:\users\21919\appdata\roaming\python\python313\site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\programdata\miniconda3\envs\ds\lib\site-packages (from kaggle) (2025.8.3)
# Requirement already satisfied: charset-normalizer in c:\programdata\miniconda3\envs\ds\lib\site-packages (from kaggle) (3.4.3)
# Requirement already satisfied: idna in c:\programdata\miniconda3\envs\ds\lib\site-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in c:\users\21919\appdata\roaming\python\python313\site-packages (from kaggle) (6.33.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\21919\appdata\roaming\python\python313\site-packages (from kaggle) (2.9.0.post0)
# Collecting python-slugify (from kaggle)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests in c:\programdata\miniconda3\envs\ds\lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: setuptools>=21.0.0 in c:\programdata\miniconda3\envs\ds\lib\site-packages (from kaggle) (78.1.1)
# Requirement already satisfied: six>=1.10 in c:\users\21919\appdata\roaming\python\python313\site-packages (from kaggle) (1.17.0)
# Collecting text-unidecode (from kaggle)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting tqdm (from kaggle)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: urllib3>=1.15.1 in c:\programdata\miniconda3\envs\ds\lib\site-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in c:\users\21919\appdata\roaming\python\python313\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: colorama in c:\programdata\miniconda3\envs\ds\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Downloading kaggle-1.7.4.5-py3-none-any.whl (181 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: text-unidecode, tqdm, python-slugify, kaggle
#
#    ---------- ----------------------------- 1/4 [tqdm]
#    ---------- ----------------------------- 1/4 [tqdm]
#    ---------- ----------------------------- 1/4 [tqdm]
#    ---------- ----------------------------- 1/4 [tqdm]
#    ---------- ----------------------------- 1/4 [tqdm]
#    ---------- ----------------------------- 1/4 [tqdm]
#    ---------- ----------------------------- 1/4 [tqdm]
#    -------------------- ------------------- 2/4 [python-slugify]
#    -------------------- ------------------- 2/4 [python-slugify]
#    ------------------------------ --------- 3/4 [kaggle]
#    ------------------------------ --------- 3/4 [kaggle]
#    ------------------------------ --------- 3/4 [kaggle]
#    ------------------------------ --------- 3/4 [kaggle]
#    ------------------------------ --------- 3/4 [kaggle]
#    ------------------------------ --------- 3/4 [kaggle]
#    ------------------------------ --------- 3/4 [kaggle]
#    ------------------------------ --------- 3/4 [kaggle]
#    ------------------------------ --------- 3/4 [kaggle]
#    ------------------------------ --------- 3/4 [kaggle]
#    ------------------------------ --------- 3/4 [kaggle]
#    ------------------------------ --------- 3/4 [kaggle]
#    ------------------------------ --------- 3/4 [kaggle]
#    ------------------------------ --------- 3/4 [kaggle]
#    ---------------------------------------- 4/4 [kaggle]
#
# Successfully installed kaggle-1.7.4.5 python-slugify-8.0.4 text-unidecode-1.3 tqdm-4.67.1
# Dataset URL: https://www.kaggle.com/datasets/yasserh/uber-fares-dataset
# License(s): CC0-1.0
# Downloading uber-fares-dataset.zip to d:\MISY225\app
#
# 数据集已成功保存为CSV文件：uber.csv
#   0%|          | 0.00/7.04M [00:00<?, ?B/s]
# 100%|██████████| 7.04M/7.04M [00:00<00:00, 941MB/s]
